# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split

pd.set_option('display.max_rows', 500)

# %%
# Define model path if you want to load a model
use_model = True
model_path = "data/model_86.pt"

# Define if you want to use CPU or GPU
use_cpu = False
gpu_available = torch.cuda.is_available()


if gpu_available and not use_cpu:
	device = torch.device("cuda:0")
	print(f"GPU Support Enabled, Using: {torch.cuda.get_device_name(0)}")  # Prints the name of the GPU
else:
	device = torch.device("cpu")
	print("No GPU available, using CPU")
# Out:
# GPU Support Enabled, Using: NVIDIA GeForce RTX 2070 SUPER

# %%
df = pd.read_csv('data/final_data.csv')

# %%
df.head()
# Out:
#    status  orbital_period  semi_major_axis  planet_radius  transit_duration  \
# 0       1        0.571336          0.01312          1.820           1.79000
# 1       1        2.180535          0.03558         16.197           2.92780
# 2       1        3.595100          0.04700          1.950           4.33000
# 3       1        1.673902          0.04220          3.450           1.60560
# 4       1        0.658524          0.01306          3.300           0.33336
#
#    insolation_flux  equilibrium_temperature  kepler_magnitude  stellar_radius  \
# 0           4293.0                   2063.0            11.958            0.95
# 1           1860.0                   1828.0            11.468            1.26
# 2           1037.0                   1616.0            11.364            1.71
# 3            990.0                   1094.0            10.408            1.19
# 4            879.5                   1515.0            11.386            0.70
#
#    stellar_effective_temperature  stellar_surface_gravity  stellar_mass  \
# 0                         5496.0                     4.42          0.92
# 1                         6360.0                     4.34          1.26
# 2                         5430.0                     3.99          1.05
# 3                         6120.0                     4.36          1.18
# 4                         4285.0                     4.58          0.69
#
#    stellar_metallicity
# 0                0.060
# 1                0.137
# 2                0.200
# 3                0.140
# 4               -0.120

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7386 entries, 0 to 7385
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   status                         7386 non-null   int64
#  1   orbital_period                 7386 non-null   float64
#  2   semi_major_axis                7386 non-null   float64
#  3   planet_radius                  7386 non-null   float64
#  4   transit_duration               7386 non-null   float64
#  5   insolation_flux                7386 non-null   float64
#  6   equilibrium_temperature        7386 non-null   float64
#  7   kepler_magnitude               7386 non-null   float64
#  8   stellar_radius                 7386 non-null   float64
#  9   stellar_effective_temperature  7386 non-null   float64
#  10  stellar_surface_gravity        7386 non-null   float64
#  11  stellar_mass                   7386 non-null   float64
#  12  stellar_metallicity            7386 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 750.3 KB

# %%
df.describe()
# Out:
#             status  orbital_period  semi_major_axis  planet_radius  \
# count  7386.000000     7386.000000       7386.00000    7386.000000
# mean      0.382480       49.648224          0.18903     102.287896
# std       0.486026      117.546780          0.29365    3166.460197
# min       0.000000        0.241843          0.00590       0.080000
# 25%       0.000000        2.237506          0.03340       1.510000
# 50%       0.000000        7.739694          0.07510       2.620000
# 75%       1.000000       27.392805          0.17610      23.802500
# max       1.000000     3650.000000          4.50000  200346.000000
#
#        transit_duration  insolation_flux  equilibrium_temperature  \
# count       7386.000000     7.386000e+03              7386.000000
# mean           5.708500     9.209798e+03              1151.313837
# std            6.833667     1.777975e+05               895.020440
# min            0.104600     2.000000e-02                92.000000
# 25%            2.486083     2.714250e+01               582.000000
# 50%            3.842320     1.783800e+02               932.000000
# 75%            6.238627     1.122505e+03              1476.000000
# max          138.540000     1.094755e+07             14667.000000
#
#        kepler_magnitude  stellar_radius  stellar_effective_temperature  \
# count       7386.000000     7386.000000                    7386.000000
# mean          14.236909        1.720254                    5707.695911
# std            1.413719        5.900127                     822.079435
# min            6.966000        0.116000                    2661.000000
# 25%           13.405000        0.827000                    5301.500000
# 50%           14.495000        0.997000                    5767.000000
# 75%           15.303500        1.342750                    6113.000000
# max           20.003000      229.908000                   15896.000000
#
#        stellar_surface_gravity  stellar_mass  stellar_metallicity
# count              7386.000000   7386.000000          7386.000000
# mean                  4.313374      1.021002            -0.126083
# std                   0.433957      0.351371             0.282097
# min                   0.047000      0.094000            -2.500000
# 25%                   4.220000      0.840000            -0.260000
# 50%                   4.438000      0.972000            -0.100000
# 75%                   4.544000      1.099000             0.070000
# max                   5.283000      3.686000             0.560000

# %%
# Nomalize data
df = (df - df.min()) / (df.max() - df.min())
df.describe()
# Out:
#             status  orbital_period  semi_major_axis  planet_radius  \
# count  7386.000000     7386.000000      7386.000000    7386.000000
# mean      0.382480        0.013537         0.040749       0.000510
# std       0.486026        0.032207         0.065341       0.015805
# min       0.000000        0.000000         0.000000       0.000000
# 25%       0.000000        0.000547         0.006119       0.000007
# 50%       0.000000        0.002054         0.015398       0.000013
# 75%       1.000000        0.007439         0.037872       0.000118
# max       1.000000        1.000000         1.000000       1.000000
#
#        transit_duration  insolation_flux  equilibrium_temperature  \
# count       7386.000000      7386.000000              7386.000000
# mean           0.040480         0.000841                 0.072680
# std            0.049364         0.016241                 0.061408
# min            0.000000         0.000000                 0.000000
# 25%            0.017203         0.000002                 0.033619
# 50%            0.027000         0.000016                 0.057633
# 75%            0.044310         0.000103                 0.094957
# max            1.000000         1.000000                 1.000000
#
#        kepler_magnitude  stellar_radius  stellar_effective_temperature  \
# count       7386.000000     7386.000000                    7386.000000
# mean           0.557713        0.006981                       0.230200
# std            0.108439        0.025676                       0.062114
# min            0.000000        0.000000                       0.000000
# 25%            0.493902        0.003094                       0.199509
# 50%            0.577510        0.003834                       0.234681
# 75%            0.639526        0.005339                       0.260824
# max            1.000000        1.000000                       1.000000
#
#        stellar_surface_gravity  stellar_mass  stellar_metallicity
# count              7386.000000   7386.000000          7386.000000
# mean                  0.814815      0.258074             0.775790
# std                   0.082880      0.097820             0.092189
# min                   0.000000      0.000000             0.000000
# 25%                   0.796982      0.207684             0.732026
# 50%                   0.838617      0.244432             0.784314
# 75%                   0.858862      0.279788             0.839869
# max                   1.000000      1.000000             1.000000

# %%
# Split into train and test
train_df, test_df = train_test_split(df, test_size=0.2)

# %%
# Prep training data
x_train = train_df.drop('status', axis=1)
y_train = train_df['status']

# Convert to numpy arrays
x_train = np.array(x_train,dtype=np.float32)
y_train = np.array(y_train,dtype=np.float32).reshape(-1,1)

# Convert to tensors
X_train = torch.tensor(x_train, dtype=torch.float32)
Y_train = torch.tensor(y_train, dtype=torch.float32)

print(f"Input dimensions: {x_train.shape[1]}")
print(f"Output dimensions: {y_train.shape[1]}")
# Out:
# Input dimensions: 12
# Output dimensions: 1

# %%
# Prep testing data
x_test = test_df.drop('status', axis=1)
y_test = test_df['status']

# Convert to numpy arrays
x_test = np.array(x_test,dtype=np.float32)
y_test = np.array(y_test,dtype=np.float32).reshape(-1,1)

# Convert to tensors
X_test = torch.tensor(x_test, dtype=torch.float32)
Y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
# Creating the model
models = []
hidden_nodes = np.arange(12,50,1)
for h_n in hidden_nodes:
    print(f"Creating model with {h_n} hidden nodes")
    models.append(
        nn.Sequential(
            nn.Linear(12, h_n),
            nn.ReLU(),
            nn.Linear(h_n, 1),
            nn.ReLU(),
            nn.Linear(1, 1),
            nn.Sigmoid()
        )
    )
    models.append(
        nn.Sequential(
            nn.Linear(12, h_n),
            nn.ReLU(),
            nn.Linear(h_n, h_n),
            nn.ReLU(),
            nn.Linear(h_n, 1),
            nn.ReLU(),
            nn.Linear(1, 1),
            nn.Sigmoid()
        )
    )
    models.append(
        nn.Sequential(
            nn.Linear(12, h_n),
            nn.ReLU(),
            nn.Linear(h_n, h_n),
            nn.ReLU(),
            nn.Linear(h_n, h_n),
            nn.ReLU(),
            nn.Linear(h_n, 1),
            nn.ReLU(),
            nn.Linear(1, 1),
            nn.Sigmoid()
        )
    )
# Out:
# Creating model with 12 hidden nodes
# Creating model with 13 hidden nodes
# Creating model with 14 hidden nodes
# Creating model with 15 hidden nodes
# Creating model with 16 hidden nodes
# Creating model with 17 hidden nodes
# Creating model with 18 hidden nodes
# Creating model with 19 hidden nodes
# Creating model with 20 hidden nodes
# Creating model with 21 hidden nodes
# Creating model with 22 hidden nodes
# Creating model with 23 hidden nodes
# Creating model with 24 hidden nodes
# Creating model with 25 hidden nodes
# Creating model with 26 hidden nodes
# Creating model with 27 hidden nodes
# Creating model with 28 hidden nodes
# Creating model with 29 hidden nodes
# Creating model with 30 hidden nodes
# Creating model with 31 hidden nodes
# Creating model with 32 hidden nodes
# Creating model with 33 hidden nodes
# Creating model with 34 hidden nodes
# Creating model with 35 hidden nodes
# Creating model with 36 hidden nodes
# Creating model with 37 hidden nodes
# Creating model with 38 hidden nodes
# Creating model with 39 hidden nodes
# Creating model with 40 hidden nodes
# Creating model with 41 hidden nodes
# Creating model with 42 hidden nodes
# Creating model with 43 hidden nodes
# Creating model with 44 hidden nodes
# Creating model with 45 hidden nodes
# Creating model with 46 hidden nodes
# Creating model with 47 hidden nodes
# Creating model with 48 hidden nodes
# Creating model with 49 hidden nodes

# %%
# Define loss function
loss_fn = nn.BCELoss()  # binary cross entropy

# Define optimizer
optimizers = []
for model in models:
	optimizers.append(optim.Adam(model.parameters(), lr=0.001))

# %%
# Transfer model to GPU if available
if gpu_available and not use_cpu:
	print(f"Transferring model to GPU: {torch.cuda.get_device_name(0)}")
	for model in models:
		model = model.cuda()
		loss_fn = loss_fn.cuda()
# Out:
# Transferring model to GPU: NVIDIA GeForce RTX 2070 SUPER

# %%
# Define training parameters
n_epochs = 100
batch_size = 10

# Train the models
for epoch in range(n_epochs):
    for i in range(0, len(X_train), batch_size):
        # Get batch
        X_batch = X_train[i:i+batch_size]
        Y_batch = Y_train[i:i+batch_size]

        # Transfer to GPU if available
        if gpu_available and not use_cpu:
            X_batch = X_batch.cuda()
            Y_batch = Y_batch.cuda()

        # Feedforward
        for model, optimizer in zip(models, optimizers):
            Y_pred = model(X_batch)

            # Calculate loss
            loss = loss_fn(Y_pred, Y_batch)

            # Backpropagate error and update weights
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

    # Print loss after each epoch
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 0.7241796255111694
# Finished epoch 1, latest loss 0.72336745262146
# Finished epoch 2, latest loss 0.7230351567268372
# Finished epoch 3, latest loss 0.722898542881012
# Finished epoch 4, latest loss 0.7228422164916992
# Finished epoch 5, latest loss 0.722818911075592
# Finished epoch 6, latest loss 0.7228093147277832
# Finished epoch 7, latest loss 0.7228052616119385
# Finished epoch 8, latest loss 0.7228035926818848
# Finished epoch 9, latest loss 0.7228029370307922
# Finished epoch 10, latest loss 0.7228026390075684
# Finished epoch 11, latest loss 0.7228025197982788
# Finished epoch 12, latest loss 0.722802460193634
# Finished epoch 13, latest loss 0.7228024005889893
# Finished epoch 14, latest loss 0.7228024005889893
# Finished epoch 15, latest loss 0.7228024005889893
# Finished epoch 16, latest loss 0.7228024005889893
# Finished epoch 17, latest loss 0.7228024005889893
# Finished epoch 18, latest loss 0.7228023409843445
# Finished epoch 19, latest loss 0.7228023409843445
# Finished epoch 20, latest loss 0.7228023409843445
# Finished epoch 21, latest loss 0.7228023409843445
# Finished epoch 22, latest loss 0.7228023409843445
# Finished epoch 23, latest loss 0.7228024005889893
# Finished epoch 24, latest loss 0.7228024005889893
# Finished epoch 25, latest loss 0.7228024005889893
# Finished epoch 26, latest loss 0.7228024005889893
# Finished epoch 27, latest loss 0.7228024005889893
# Finished epoch 28, latest loss 0.7228024005889893
# Finished epoch 29, latest loss 0.7228024005889893
# Finished epoch 30, latest loss 0.7228024005889893
# Finished epoch 31, latest loss 0.7228024005889893
# Finished epoch 32, latest loss 0.7228024005889893
# Finished epoch 33, latest loss 0.7228024005889893
# Finished epoch 34, latest loss 0.7228024005889893
# Finished epoch 35, latest loss 0.7228024005889893
# Finished epoch 36, latest loss 0.7228024005889893
# Finished epoch 37, latest loss 0.7228024005889893
# Finished epoch 38, latest loss 0.7228024005889893
# Finished epoch 39, latest loss 0.7228024005889893
# Finished epoch 40, latest loss 0.7228024005889893
# Finished epoch 41, latest loss 0.7228024005889893
# Finished epoch 42, latest loss 0.7228024005889893
# Finished epoch 43, latest loss 0.7228024005889893
# Finished epoch 44, latest loss 0.7228024005889893
# Finished epoch 45, latest loss 0.7228024005889893
# Finished epoch 46, latest loss 0.7228024005889893
# Finished epoch 47, latest loss 0.7228024005889893
# Finished epoch 48, latest loss 0.7228024005889893
# Finished epoch 49, latest loss 0.7228024005889893
# Finished epoch 50, latest loss 0.7228024005889893
# Finished epoch 51, latest loss 0.7228024005889893
# Finished epoch 52, latest loss 0.7228024005889893
# Finished epoch 53, latest loss 0.7228024005889893
# Finished epoch 54, latest loss 0.7228024005889893
# Finished epoch 55, latest loss 0.7228024005889893
# Finished epoch 56, latest loss 0.7228024005889893
# Finished epoch 57, latest loss 0.7228024005889893
# Finished epoch 58, latest loss 0.7228024005889893
# Finished epoch 59, latest loss 0.7228024005889893
# Finished epoch 60, latest loss 0.7228024005889893
# Finished epoch 61, latest loss 0.7228024005889893
# Finished epoch 62, latest loss 0.7228024005889893
# Finished epoch 63, latest loss 0.7228024005889893
# Finished epoch 64, latest loss 0.7228024005889893
# Finished epoch 65, latest loss 0.7228024005889893
# Finished epoch 66, latest loss 0.7228024005889893
# Finished epoch 67, latest loss 0.7228024005889893
# Finished epoch 68, latest loss 0.7228024005889893
# Finished epoch 69, latest loss 0.7228024005889893
# Finished epoch 70, latest loss 0.7228024005889893
# Finished epoch 71, latest loss 0.7228024005889893
# Finished epoch 72, latest loss 0.7228024005889893
# Finished epoch 73, latest loss 0.7228024005889893
# Finished epoch 74, latest loss 0.7228024005889893
# Finished epoch 75, latest loss 0.7228024005889893
# Finished epoch 76, latest loss 0.7228024005889893
# Finished epoch 77, latest loss 0.7228024005889893
# Finished epoch 78, latest loss 0.7228024005889893
# Finished epoch 79, latest loss 0.7228024005889893
# Finished epoch 80, latest loss 0.7228024005889893
# Finished epoch 81, latest loss 0.7228024005889893
# Finished epoch 82, latest loss 0.7228024005889893
# Finished epoch 83, latest loss 0.7228024005889893
# Finished epoch 84, latest loss 0.7228024005889893
# Finished epoch 85, latest loss 0.7228024005889893
# Finished epoch 86, latest loss 0.7228024005889893
# Finished epoch 87, latest loss 0.7228024005889893
# Finished epoch 88, latest loss 0.7228024005889893
# Finished epoch 89, latest loss 0.7228024005889893
# Finished epoch 90, latest loss 0.7228024005889893
# Finished epoch 91, latest loss 0.7228024005889893
# Finished epoch 92, latest loss 0.7228024005889893
# Finished epoch 93, latest loss 0.7228024005889893
# Finished epoch 94, latest loss 0.7228024005889893
# Finished epoch 95, latest loss 0.7228024005889893
# Finished epoch 96, latest loss 0.7228024005889893
# Finished epoch 97, latest loss 0.7228024005889893
# Finished epoch 98, latest loss 0.7228024005889893
# Finished epoch 99, latest loss 0.7228024005889893

# %%
# Make predictions
X_test = X_test.to(device)
with torch.no_grad():
    # Run the model on the test data and transfer the result to CPU
    Y_pred = []
    for model in models:
        Y_pred.append(model(X_test).to("cpu"))

# %%
# Calculate the accuracy
best_accuracy = 0.0
for y_pred, model in zip(Y_pred, models):
	accuracy = (y_pred.round() == Y_test).float().mean()

	# Save best model
	if accuracy > best_accuracy:
		best_accuracy = accuracy
		best_model = model

	# Print accuracy
	print(f"Accuracy {accuracy}")

print(f"Best accuracy {best_accuracy}")
print(f"Best model {best_model}")
# Out:
# Accuracy 0.8525033593177795
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.8619756698608398
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.8538565635681152
# Accuracy 0.8619756698608398
# Accuracy 0.8646820187568665
# Accuracy 0.6089310050010681
# Accuracy 0.8592692613601685
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.8612990379333496
# Accuracy 0.8640053868293762
# Accuracy 0.8612990379333496
# Accuracy 0.8558863401412964
# Accuracy 0.8673883676528931
# Accuracy 0.6089310050010681
# Accuracy 0.8606224656105042
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.858592689037323
# Accuracy 0.8640053868293762
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.8707712888717651
# Accuracy 0.6089310050010681
# Accuracy 0.8667117953300476
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.8680649399757385
# Accuracy 0.8599458932876587
# Accuracy 0.6089310050010681
# Accuracy 0.8694181442260742
# Accuracy 0.8592692613601685
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.8640053868293762
# Accuracy 0.8558863401412964
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.8660351634025574
# Accuracy 0.8633288145065308
# Accuracy 0.6089310050010681
# Accuracy 0.8653585910797119
# Accuracy 0.8707712888717651
# Accuracy 0.8714479207992554
# Accuracy 0.6089310050010681
# Accuracy 0.8721244931221008
# Accuracy 0.8680649399757385
# Accuracy 0.8734776973724365
# Accuracy 0.858592689037323
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.8619756698608398
# Accuracy 0.8633288145065308
# Accuracy 0.6089310050010681
# Accuracy 0.8680649399757385
# Accuracy 0.6089310050010681
# Accuracy 0.8714479207992554
# Accuracy 0.6089310050010681
# Accuracy 0.8694181442260742
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.8538565635681152
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.8640053868293762
# Accuracy 0.8680649399757385
# Accuracy 0.6089310050010681
# Accuracy 0.8680649399757385
# Accuracy 0.8667117953300476
# Accuracy 0.8633288145065308
# Accuracy 0.8606224656105042
# Accuracy 0.8660351634025574
# Accuracy 0.8579161167144775
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.8606224656105042
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.8626522421836853
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.8694181442260742
# Accuracy 0.6089310050010681
# Accuracy 0.8660351634025574
# Accuracy 0.8728010654449463
# Accuracy 0.8626522421836853
# Accuracy 0.8721244931221008
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Accuracy 0.8667117953300476
# Accuracy 0.6089310050010681
# Accuracy 0.8646820187568665
# Accuracy 0.8640053868293762
# Accuracy 0.6089310050010681
# Accuracy 0.6089310050010681
# Best accuracy 0.8734776973724365
# Best model Sequential(
#   (0): Linear(in_features=12, out_features=31, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=31, out_features=31, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=31, out_features=1, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=1, out_features=1, bias=True)
#   (7): Sigmoid()
# )

# %%
torch.save(best_model, "data/model_87_2hidden_31_nodes.pt")

# %% [markdown]
# Accuracy 0.6136671304702759 Accuracy 0.8464140892028809
# Accuracy 0.6136671304702759 Accuracy 0.8531799912452698
# Accuracy 0.8430311083793640 Accuracy 0.8281461596488953
# Accuracy 0.6136671304702759 Accuracy 0.8396481871604919
# Accuracy 0.6136671304702759 Accuracy 0.8450608849525452
# Accuracy 0.8443843126296997 Accuracy 0.6028416752815247
# Accuracy 0.6136671304702759 Accuracy 0.6028416752815247
# Accuracy 0.6136671304702759 Accuracy 0.6028416752815247
# Accuracy 0.6136671304702759 Accuracy 0.6028416752815247
# Accuracy 0.6136671304702759 Accuracy 0.6028416752815247
# Accuracy 0.8511502146720886 Accuracy 0.6028416752815247
# Accuracy 0.8477672338485718 Accuracy 0.8579161167144775

# %%
best_accuracy
# Out:
# tensor(0.8735)
